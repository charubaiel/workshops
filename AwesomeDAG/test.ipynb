# %%
import pandas as pd

# %%
titles = pd.read_pickle('/home/charubaiel/workflow/workshops/AwesomeDAG/tmpdycmg2tt/storage/clean_titles')

# %%
dd = pd.read_parquet('data/imdb_data.parquet')

# %%
dd
# Out:
#           titleType                   primaryTitle  isAdult  startYear  \
# tconst
# tt0000009     movie                     Miss Jerry        0     1894.0
# tt0000147     movie  The Corbett-Fitzsimmons Fight        0     1897.0
# tt0000147     movie  The Corbett-Fitzsimmons Fight        0     1897.0
# tt0000147     movie  The Corbett-Fitzsimmons Fight        0     1897.0
# tt0000574     movie    The Story of the Kelly Gang        0     1906.0
# ...             ...                            ...      ...        ...
# tt9916190     movie                      Safeguard        0     2020.0
# tt9916190     movie                      Safeguard        0     2020.0
# tt9916270     movie       Il talento del calabrone        0     2020.0
# tt9916362     movie                          Coven        0     2020.0
# tt9916362     movie                          Coven        0     2020.0
#
#            runtimeMinutes  genres_Action  genres_Adult  genres_Adventure  \
# tconst
# ...
