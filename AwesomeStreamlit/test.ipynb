# %%
import pandas as pd
from __init__ import ROOT

# %%
dd = pd.read_parquet(f'{ROOT}/AwesomeDAG/data/imdb_data.parquet')

# %%
dd['actor'] = dd.apply(lambda row: set(row.fillna('')['actor']) | set(row.fillna('')['actress']) ,axis=1).apply(list)
dd = dd.drop('actress',axis=1)

# %%
dd.columns
# Out:
# Index(['titleType', 'primaryTitle', 'originalTitle', 'isAdult', 'startYear',
#        'endYear', 'runtimeMinutes', 'genres', 'averageRating', 'numVotes',
#        'actor', 'cinematographer', 'directors', 'writers'],
#       dtype='object')

# %%
dd
# Out:
#           titleType                   primaryTitle  \
# tconst
# tt0000009     movie                     Miss Jerry
# tt0000147     movie  The Corbett-Fitzsimmons Fight
# tt0000574     movie    The Story of the Kelly Gang
# tt0001892     movie                 Den sorte drøm
# tt0002101     movie                      Cleopatra
# ...             ...                            ...
# tt9914942     movie         Life Without Sara Amat
# tt9914972     movie                 Blind Ambition
# tt9916190     movie                      Safeguard
# tt9916270     movie       Il talento del calabrone
# tt9916362     movie                          Coven
#
#                            originalTitle  isAdult  startYear endYear  \
# tconst
# tt0000009                     Miss Jerry        0     1894.0      \N
# tt0000147  The Corbett-Fitzsimmons Fight        0     1897.0      \N
# tt0000574    The Story of the Kelly Gang        0     1906.0      \N
# tt0001892                 Den sorte drøm        0     1911.0      \N
# tt0002101                      Cleopatra        0     1912.0      \N
# ...                                  ...      ...        ...     ...
# tt9914942     La vida sense la Sara Amat        0     2019.0      \N
# tt9914972                 Blind Ambition        0     2021.0      \N
# tt9916190                      Safeguard        0     2020.0      \N
# tt9916270       Il talento del calabrone        0     2020.0      \N
# tt9916362                       Akelarre        0     2020.0      \N
#
#            runtimeMinutes                          genres  averageRating  \
# tconst
# tt0000009            45.0                       [Romance]            5.3
# tt0000147           100.0      [Documentary, News, Sport]            5.2
# tt0000574            70.0  [Action, Adventure, Biography]            6.0
# tt0001892            53.0                         [Drama]            5.8
# tt0002101           100.0                [Drama, History]            5.1
# ...                   ...                             ...            ...
# tt9914942            74.0                         [Drama]            6.7
# tt9914972            96.0                   [Documentary]            7.2
# tt9916190            95.0   [Action, Adventure, Thriller]            3.7
# tt9916270            84.0                      [Thriller]            5.8
# tt9916362            92.0                [Drama, History]            6.4
#
#            numVotes                                              actor  \
# tconst
# tt0000009       204  [Chauncey Depew, Blanche Bayliss, William Cour...
# tt0000147       466                                                 []
# tt0000574       815  [Elizabeth Tait, John Tait, Norman Campbell, N...
# tt0001892       243  [Asta Nielsen, Mary Hagen, Valdemar Psilander,...
# tt0002101       546  [Miss Robson, James R. Waite, Charles Sindelar...
# ...             ...                                                ...
# tt9914942       171  [Maria Morera, Francesca Piñón, Biel Rossell, ...
# tt9914972       251                                                 []
# tt9916190       241  [Sean Cronin, Akie Kotabe, Patrick Gallagher, ...
# tt9916270      1400  [Sergio Castellitto, Lorenzo Richelmy, Marina ...
# tt9916362      5205  [Alex Brendemühl, Garazi Urkola, Daniel Fanego...
#
#                          cinematographer           directors  \
# tconst
# tt0000009                           None     Alexander Black
# tt0000147                           None     Enoch J. Rector
# tt0000574                  [Orrie Perry]        Charles Tait
# tt0001892  [Adam Johansen, Guido Seeber]           Urban Gad
# tt0002101                           None  Charles L. Gaskill
# ...                                  ...                 ...
# tt9914942                 [Gris Jordana]           Laura Jou
# tt9914972               [Martin McGrath]                None
# tt9916190      [Matt Perren, Tom Walder]     Fraser Precious
# tt9916270             [Maurizio Calvesi]      Giacomo Cimini
# tt9916362                           None        Pablo Agüero
#
#                                                      writers
# tconst
# tt0000009                                  [Alexander Black]
# tt0000147                                             [None]
# tt0000574                                     [Charles Tait]
# tt0001892            [Urban Gad, Gebhard Schätzler-Perasini]
# tt0002101             [Victorien Sardou, Charles L. Gaskill]
# ...                                                      ...
# tt9914942                             [Coral Cruz, Pep Puig]
# tt9914972  [Robert Coe, Paul Murphy, Madeleine Ross, Warw...
# tt9916190                                  [Fraser Precious]
# tt9916270                 [Giacomo Cimini, Lorenzo Collalti]
# tt9916362                     [Pablo Agüero, Katell Guillou]
#
# [136538 rows x 14 columns]

# %%
df_exp = dd.explode(column=['actor']).explode('writers')

# %%
df_exp
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_6466/4205773643.py in <module>
# ----> 1 df_exp
#
# NameError: name 'df_exp' is not defined

# %%
dd.groupby(['actor','directors','writers']).agg({'averageRating':'mean','primaryTitle':['unique','count']})
# Out:
#                                                                     averageRating  \
#                                                                              mean
# actor                    directors         writers
# 'Cousin Brucie' Morrow   Fred Barzyk       David Odell                        7.2
#                                            David R. Loxton                    7.2
#                                            Fred Barzyk                        7.2
#                                            Kurt Vonnegut Jr.                  7.2
# 'Ducky' Louie            Phil Karlson      Agnes Christine Johnston           6.1
# ...                                                                           ...
# Þórhildur Ýr Arnardóttir Þráinn Bertelsson Guðrún Helgadóttir                 6.8
#                                            Þráinn Bertelsson                  6.8
# Þórir Waagfjörð          Michael Chapman   Dale Herd                          5.2
#                                            Michael Chapman                    5.2
#                                            Paul R. Gurian                     5.2
#
#                                                                                     primaryTitle  \
#                                                                                           unique
# actor                    directors         writers
# 'Cousin Brucie' Morrow   Fred Barzyk       David Odell               [Between Time and Timbuktu]
#                                            David R. Loxton           [Between Time and Timbuktu]
#                                            Fred Barzyk               [Between Time and Timbuktu]
#                                            Kurt Vonnegut Jr.         [Between Time and Timbuktu]
# 'Ducky' Louie            Phil Karlson      Agnes Christine Johnston                 [Black Gold]
# ...                                                                                          ...
# Þórhildur Ýr Arnardóttir Þráinn Bertelsson Guðrún Helgadóttir                        [The Twins]
#                                            Þráinn Bertelsson                         [The Twins]
# Þórir Waagfjörð          Michael Chapman   Dale Herd                          [The Viking Sagas]
#                                            Michael Chapman                    [The Viking Sagas]
#                                            Paul R. Gurian                     [The Viking Sagas]
#
#
#                                                                     count
# actor                    directors         writers
# 'Cousin Brucie' Morrow   Fred Barzyk       David Odell                  1
#                                            David R. Loxton              1
#                                            Fred Barzyk                  1
#                                            Kurt Vonnegut Jr.            1
# 'Ducky' Louie            Phil Karlson      Agnes Christine Johnston     1
# ...                                                                   ...
# Þórhildur Ýr Arnardóttir Þráinn Bertelsson Guðrún Helgadóttir           1
#                                            Þráinn Bertelsson            1
# Þórir Waagfjörð          Michael Chapman   Dale Herd                    1
#                                            Michael Chapman              1
#                                            Paul R. Gurian               1
#
# [939294 rows x 3 columns]
